# %%
import pandas as pd
import numpy as np
from keras import models
from keras import layers
from sklearn.metrics import confusion_matrix, f1_score
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# %matplotlib inline
np.random.seed(123)

# %%
train = ImageDataGenerator(rescale=1./255).flow_from_directory( 
        directory = 'chest_xray/train',
        batch_size = 5216)
# Out:
# Found 5216 images belonging to 2 classes.

# %%
test = ImageDataGenerator(rescale=1./255).flow_from_directory( 
        directory = 'chest_xray/test',
        batch_size = 624)
# Out:
# Found 624 images belonging to 2 classes.

# %%
val = ImageDataGenerator(rescale=1./255).flow_from_directory( 
        directory = 'chest_xray/val',
        batch_size = 16)
# Out:
# Found 16 images belonging to 2 classes.

# %%
# Spliting images and labels
val_images, val_labels = next(val)
test_images, test_labels = next(test)
train_images, train_labels = next(train)

# %%
val_labels = np.reshape(val_labels[:,0], (16,1))
test_labels = np.reshape(test_labels[:,0], (624,1))
train_labels = np.reshape(train_labels[:,0], (5216,1))

# %%
cnn = models.Sequential()
cnn.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(256, 256,  3)))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(32, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(32, activation='relu'))
cnn.add(layers.Dense(1, activation='sigmoid'))

cnn.compile(loss='binary_crossentropy',
              optimizer="sgd",
              metrics=['acc'])

# %%
cnn1 = cnn.fit(train_images,
                    train_labels,
                    epochs=5,
                    batch_size=50,
                    validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 105/105 [==============================] - 355s 3s/step - loss: 0.5076 - acc: 0.7431 - val_loss: 1.4515 - val_acc: 0.5000
# Epoch 2/5
# 105/105 [==============================] - 351s 3s/step - loss: 0.3742 - acc: 0.8434 - val_loss: 1.1888 - val_acc: 0.6250
# Epoch 3/5
# 105/105 [==============================] - 344s 3s/step - loss: 0.2461 - acc: 0.9051 - val_loss: 0.5470 - val_acc: 0.7500
# Epoch 4/5
# 105/105 [==============================] - 322s 3s/step - loss: 0.1973 - acc: 0.9254 - val_loss: 0.3082 - val_acc: 0.9375
# Epoch 5/5
# 105/105 [==============================] - 316s 3s/step - loss: 0.1630 - acc: 0.9387 - val_loss: 0.2788 - val_acc: 0.9375

# %%
hist_cnn = cnn1.history
loss_values = hist_cnn['loss']
val_loss_values = hist_cnn['val_loss']
acc_values = hist_cnn['acc'] 
val_acc_values = hist_cnn['val_acc']


epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(15,4))
plt.subplot(121)
plt.plot(epochs, loss_values, 'g.', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')

plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc_values, 'r.', label='Training acc')
plt.plot(epochs, val_acc_values, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
results_train = cnn.evaluate(train_images, train_labels)
results_test = cnn.evaluate(test_images, test_labels)
print(results_train, results_test)
# Out:
# 163/163 [==============================] - 101s 622ms/step - loss: 0.1679 - acc: 0.9381
# 20/20 [==============================] - 10s 492ms/step - loss: 0.3989 - acc: 0.8237
# [0.16794078052043915, 0.9380751252174377] [0.39889293909072876, 0.8237179517745972]

# %%
def predictoneimage_cnn(model, path):
    img = load_img(path, target_size=(256, 256))
    plt.imshow(img)
    img = img_to_array(img)
    img = img/255
    img = np.expand_dims(img, axis=0)
    predict = model.predict(img)
    return predict

# %%
predictoneimage_cnn(cnn, 'chest_xray/test/NORMAL/IM-0001-0001.jpeg')
# Out:
# array([[0.8604547]], dtype=float32)

# %%
predictoneimage_cnn(cnn, 'chest_xray/test/PNEUMONIA/person1_virus_6.jpeg')
# Out:
# array([[0.00247079]], dtype=float32)
